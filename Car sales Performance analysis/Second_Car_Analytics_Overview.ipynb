# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadJundullah/Data-Analytics/blob/main/Car%20sales%20analysis/Second_Car_Analytics_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/gdrive')

pd.set_option('display.max_columns', None)
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.set_palette('Spectral')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Car_details/Car_details.csv')
df
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 1          Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 2         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 3            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 4     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# ...                             ...   ...            ...        ...     ...
# 8122              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123          Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125                Tata Indigo CR4  2013         290000      25000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 1     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 2     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 3     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# 4     Individual       Manual           First Owner  20.14 kmpl  1197 CC
# ...          ...          ...                   ...         ...      ...
# 8122  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8123  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8124  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8125  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 1         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 2         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 3       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# 4      81.86 bhp          113.75nm@ 4000rpm    5.0
# ...          ...                        ...    ...
# 8122   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8123     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8124    73.9 bhp             190Nm@ 2000rpm    5.0
# 8125      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8127 rows x 13 columns]

# %% [markdown]
# # menghapus string format data untuk kebutuhan analisis

# %%
df['max_power'] = df['max_power'].str.replace(' bhp','')
df['max_power'] = df['max_power'].replace('', np.nan)
df['max_power'] = df['max_power'].astype('float')

# %%
df['engine'] = df['engine'].str.replace(' CC', '')
df['max_power'] = df['max_power'].astype('int')
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 1              Honda City 2017-2020 EXi  2006         158000     140000
# 2             Hyundai i20 Sportz Diesel  2010         225000     127000
# 3                Maruti Swift VXI BSIII  2007         130000     120000
# 4         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# ...                                 ...   ...            ...        ...
# 8120  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8121         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8122                  Hyundai i20 Magna  2013         320000     110000
# 8123              Hyundai Verna CRDi SX  2007         135000     119000
# 8124             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner engine  max_power  \
# 0     Diesel  Individual       Manual          Second Owner   1498        103
# 1     Petrol  Individual       Manual           Third Owner   1497         78
# 2     Diesel  Individual       Manual           First Owner   1396         90
# 3     Petrol  Individual       Manual           First Owner   1298         88
# 4     Petrol  Individual       Manual           First Owner   1197         81
# ...      ...         ...          ...                   ...    ...        ...
# 8120  Petrol  Individual       Manual          Second Owner    998         67
# 8121  Diesel  Individual       Manual          Second Owner   1396         88
# 8122  Petrol  Individual       Manual           First Owner   1197         82
# 8123  Diesel  Individual       Manual  Fourth & Above Owner   1493        110
# 8124  Diesel  Individual       Manual           First Owner   1248         73
#
#       seats
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
# ...     ...
# 8120    5.0
# 8121    5.0
# 8122    5.0
# 8123    5.0
# 8124    5.0
#
# [6712 rows x 11 columns]

# %% [markdown]
# # menghapus kolom yang tidak diperlukan

# %%
df.drop(columns=['mileage'], inplace=True)
df
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 1          Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 2         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 3            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 4     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# ...                             ...   ...            ...        ...     ...
# 8122              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123          Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125                Tata Indigo CR4  2013         290000      25000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner   engine  max_power  \
# 0     Individual       Manual          Second Owner  1498 CC     103.52
# 1     Individual       Manual           Third Owner  1497 CC      78.00
# 2     Individual       Manual           First Owner  1396 CC      90.00
# 3     Individual       Manual           First Owner  1298 CC      88.20
# 4     Individual       Manual           First Owner  1197 CC      81.86
# ...          ...          ...                   ...      ...        ...
# 8122  Individual       Manual           First Owner  1197 CC      82.85
# 8123  Individual       Manual  Fourth & Above Owner  1493 CC     110.00
# 8124  Individual       Manual           First Owner  1248 CC      73.90
# 8125  Individual       Manual           First Owner  1396 CC      70.00
# 8126  Individual       Manual           First Owner  1396 CC      70.00
#
#                          torque  seats
# 0           250Nm@ 1500-2500rpm    5.0
# 1         12.7@ 2,700(kgm@ rpm)    5.0
# 2      22.4 kgm at 1750-2750rpm    5.0
# 3         11.5@ 4,500(kgm@ rpm)    5.0
# 4             113.75nm@ 4000rpm    5.0
# ...                         ...    ...
# 8122           113.7Nm@ 4000rpm    5.0
# 8123  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8124             190Nm@ 2000rpm    5.0
# 8125        140Nm@ 1800-3000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
#
# [8127 rows x 12 columns]

# %%
df.drop(columns=['torque'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8127 entries, 0 to 8126
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8127 non-null   object
#  1   year           8127 non-null   int64
#  2   selling_price  8127 non-null   int64
#  3   km_driven      8127 non-null   int64
#  4   fuel           8127 non-null   object
#  5   seller_type    8127 non-null   object
#  6   transmission   8127 non-null   object
#  7   owner          8127 non-null   object
#  8   engine         7906 non-null   object
#  9   max_power      7911 non-null   float64
#  10  seats          7906 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 698.5+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven    max_power        seats
# count  8127.000000   8.127000e+03  8.127000e+03  7911.000000  7906.000000
# mean   2013.803987   6.382950e+05  6.981020e+04    91.520133     5.416772
# std       4.044497   8.063003e+05  5.654780e+04    35.824222     0.959637
# min    1983.000000   2.999900e+04  1.000000e+00     0.000000     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04    68.050000     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04    82.000000     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04   102.000000     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06   400.000000    14.000000

# %% [markdown]
# # menghapus data yang duplikat

# %%
df.duplicated().sum()
# Out:
# 1202

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (6925, 11)

# %%
df.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# engine           0
# max_power        0
# seats            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# # mencari outliers

# %%
df_to_plot = df.select_dtypes(include=['float','int'])
df_to_plot.plot(kind='box', subplots=True, layout=(3, 2), figsize=(7, 10))
plt.subplots_adjust(wspace=0.5);
plt.show()

# %%
numeric = df_to_plot.columns
plt.figure(figsize=(15,10))

df.hist(bins=50, ax= plt.gca(), layout=(4,4), column=numeric)
plt.tight_layout()
plt.show()

# %%
df = df.loc[df['max_power'] <= 300.00]
df = df.loc[df['km_driven'] <= 500000]

# %% [markdown]
# # data insight

# %%
fig = plt.figure(figsize=(8, 6))
sns.heatmap(df_to_plot.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
ss = StandardScaler().fit_transform(df['selling_price'].to_numpy().reshape(-1,1))
ss_df = pd.DataFrame(ss, columns=['selling_price_standard'])
scaled = pd.concat([df, ss_df], axis=1)
scaled.head()
# Out:
#                             name    year  selling_price  km_driven    fuel  \
# 0   Skoda Rapid 1.5 TDI Ambition  2014.0       370000.0   120000.0  Diesel
# 1       Honda City 2017-2020 EXi  2006.0       158000.0   140000.0  Petrol
# 2      Hyundai i20 Sportz Diesel  2010.0       225000.0   127000.0  Diesel
# 3         Maruti Swift VXI BSIII  2007.0       130000.0   120000.0  Petrol
# 4  Hyundai Xcent 1.2 VTVT E Plus  2017.0       440000.0    45000.0  Petrol
#
#   seller_type transmission         owner   engine  max_power  seats  \
# 0  Individual       Manual  Second Owner  1498 CC     103.52    5.0
# 1  Individual       Manual   Third Owner  1497 CC      78.00    5.0
# 2  Individual       Manual   First Owner  1396 CC      90.00    5.0
# 3  Individual       Manual   First Owner  1298 CC      88.20    5.0
# 4  Individual       Manual   First Owner  1197 CC      81.86    5.0
#
#    selling_price_standard
# 0               -0.303432
# 1               -0.718569
# 2               -0.587370
# 3               -0.773398
# 4               -0.166359

# %%
x = df['max_power'].to_numpy().reshape(-1, 1)
y = df['selling_price']
linear = LinearRegression().fit(x,y)


plt.figure(figsize=(8, 6))
plt.plot(x, linear.predict(x), color = 'blue')
sns.scatterplot(x=df['max_power'], y=df['selling_price'])
plt.title('pengaruh max_power terhadap selling_price')
plt.show()

# %%
x = df['engine'].to_numpy().reshape(-1, 1)
y = df['max_power']
linear = LinearRegression().fit(x,y)

plt.figure(figsize=(8, 6))
plt.plot(x, linear.predict(x), color = 'blue')
sns.scatterplot(y=df['max_power'], x=df['engine'])
plt.title('pengaruh max_power terhadap engine')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-304e051e05d6> in <cell line: 6>()
#       4
#       5 plt.figure(figsize=(8, 6))
# ----> 6 plt.plot(x, linear.predict(x), color = 'blue')
#       7 sns.scatterplot(y=df['max_power'], x=df['engine'])
#       8 plt.title('pengaruh max_power terhadap engine')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     497
#     498         if self.axes.xaxis is not None:
# --> 499             self.axes.xaxis.update_units(x)
#     500         if self.axes.yaxis is not None:
#     501             self.axes.yaxis.update_units(y)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1673         neednew = self.converter != converter
#    1674         self.converter = converter
# -> 1675         default = self.converter.default_units(data, self)
#    1676         if default is not None and self.units is None:
#    1677             self.set_units(default)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in default_units(data, axis)
#     103         # the conversion call stack is default_units -> axis_info -> convert
#     104         if axis.units is None:
# --> 105             axis.set_units(UnitData(data))
#     106         else:
#     107             axis.units.update(data)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in update(self, data)
#     212         # check if convertible to number:
#     213         convertible = True
# --> 214         for val in OrderedDict.fromkeys(data):
#     215             # OrderedDict just iterates over unique values in data.
#     216             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
x = df['year'].to_numpy().reshape(-1,1)
y = df['selling_price']
linear.fit(x,y)

plt.figure(figsize=(8, 6))
plt.plot(x, linear.predict(x), color = 'blue')
sns.scatterplot(x=df['year'], y=df['selling_price'])
plt.title('pengaruh year terhadap selling_price')
plt.show()

# %%
fuel_max_power = df.groupby('fuel')['max_power'].mean().sort_values(ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(x=fuel_max_power.index, y=fuel_max_power.values)
plt.title('max_power bedasarkan fuel')
plt.ylabel('mean max_power')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# Membuat DataFrame baru dari kolom yang diubah skala
ss = StandardScaler().fit_transform(df['year'].to_numpy().reshape(-1,1))

ss_df = pd.DataFrame(ss, columns=['year_scaled'])

# Menambahkan DataFrame baru ke DataFrame asli
scaled = pd.concat([df, ss_df], axis=1)

# Menampilkan DataFrame baru
scaled.head()
# Out:
#                             name    year  selling_price  km_driven    fuel  \
# 0   Skoda Rapid 1.5 TDI Ambition  2014.0       370000.0   120000.0  Diesel
# 1       Honda City 2017-2020 EXi  2006.0       158000.0   140000.0  Petrol
# 2      Hyundai i20 Sportz Diesel  2010.0       225000.0   127000.0  Diesel
# 3         Maruti Swift VXI BSIII  2007.0       130000.0   120000.0  Petrol
# 4  Hyundai Xcent 1.2 VTVT E Plus  2017.0       440000.0    45000.0  Petrol
#
#   seller_type transmission         owner engine  max_power  seats  year_scaled
# 0  Individual       Manual  Second Owner   1498      103.0    5.0     0.099472
# 1  Individual       Manual   Third Owner   1497       78.0    5.0    -1.953280
# 2  Individual       Manual   First Owner   1396       90.0    5.0    -0.926904
# 3  Individual       Manual   First Owner   1298       88.0    5.0    -1.696686
# 4  Individual       Manual   First Owner   1197       81.0    5.0     0.869254

# %%
x = df['year'].to_numpy().reshape(-1,1)
y = df['selling_price']
linear.fit(x,y)

plt.figure(figsize=(8, 6))
plt.plot(x, linear.predict(x), color = 'blue')
sns.scatterplot(x=df['year'], y=df['selling_price'])
plt.title('pengaruh year terhadap selling_price')
plt.show()
