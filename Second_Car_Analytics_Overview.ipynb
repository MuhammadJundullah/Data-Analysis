# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadJundullah/Data-Analytics/blob/main/Second_Car_Analytics_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/gdrive')

pd.set_option('display.max_columns', None)
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.set_palette('Spectral')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Dataset/Data Clean/Car_details_clean.csv')
df
# Out:
#       Unnamed: 0                           name  year  selling_price  \
# 0              0   Skoda Rapid 1.5 TDI Ambition  2014         370000
# 1              1       Honda City 2017-2020 EXi  2006         158000
# 2              2      Hyundai i20 Sportz Diesel  2010         225000
# 3              3         Maruti Swift VXI BSIII  2007         130000
# 4              4  Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# ...          ...                            ...   ...            ...
# 7900        8122              Hyundai i20 Magna  2013         320000
# 7901        8123          Hyundai Verna CRDi SX  2007         135000
# 7902        8124         Maruti Swift Dzire ZDi  2009         382000
# 7903        8125                Tata Indigo CR4  2013         290000
# 7904        8126                Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission                 owner  \
# ...

# %% [markdown]
# # menghapus kolom yang ga digunakan

# %%
df.drop(columns=['mileage'], inplace=True)
df
# Out:
#       Unnamed: 0                           name  year  selling_price  \
# 0              0   Skoda Rapid 1.5 TDI Ambition  2014         370000
# 1              1       Honda City 2017-2020 EXi  2006         158000
# 2              2      Hyundai i20 Sportz Diesel  2010         225000
# 3              3         Maruti Swift VXI BSIII  2007         130000
# 4              4  Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# ...          ...                            ...   ...            ...
# 7900        8122              Hyundai i20 Magna  2013         320000
# 7901        8123          Hyundai Verna CRDi SX  2007         135000
# 7902        8124         Maruti Swift Dzire ZDi  2009         382000
# 7903        8125                Tata Indigo CR4  2013         290000
# 7904        8126                Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission                 owner  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 1          Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 2         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 3            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 4     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# ...                             ...   ...            ...        ...     ...
# 7900              Hyundai i20 Magna  2013         320000     110000  Petrol
# 7901          Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 7902         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 7903                Tata Indigo CR4  2013         290000      25000  Diesel
# 7904                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7905 entries, 0 to 7904
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7905 non-null   object
#  1   year           7905 non-null   int64
#  2   selling_price  7905 non-null   int64
#  3   km_driven      7905 non-null   int64
#  4   fuel           7905 non-null   object
#  5   seller_type    7905 non-null   object
#  6   transmission   7905 non-null   object
#  7   owner          7905 non-null   object
#  8   engine         7905 non-null   float64
#  9   max_power      7905 non-null   float64
#  10  seats          7905 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 679.5+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven       engine    max_power  \
# count  7905.000000   7.905000e+03  7.905000e+03  7905.000000  7905.000000
# mean   2013.983934   6.498390e+05  6.917901e+04  1458.735484    91.589598
# std       3.863940   8.136311e+05  5.678940e+04   503.919358    35.748930
# min    1994.000000   2.999900e+04  1.000000e+00   624.000000    32.800000
# 25%    2012.000000   2.700000e+05  3.500000e+04  1197.000000    68.050000
# 50%    2015.000000   4.500000e+05  6.000000e+04  1248.000000    82.000000
# 75%    2017.000000   6.900000e+05  9.520000e+04  1582.000000   102.000000
# max    2020.000000   1.000000e+07  2.360457e+06  3604.000000   400.000000
#
#              seats
# count  7905.000000
# mean      5.416445
# std       0.959257
# min       2.000000
# 25%       5.000000
# 50%       5.000000
# 75%       5.000000
# max      14.000000

# %% [markdown]
# # menghapus data yang duplikat

# %%
df.duplicated().sum()
# Out:
# 1189

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (6716, 11)

# %%
df.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# engine           0
# max_power        0
# seats            0
# dtype: int64

# %% [markdown]
# # mencari outliers

# %%
df_to_plot = df.select_dtypes(include=['float','int'])
df_to_plot.plot(kind='box', subplots=True, layout=(3, 2), figsize=(7, 10))
plt.subplots_adjust(wspace=0.5);
plt.show()

# %%
numeric = df_to_plot.columns
plt.figure(figsize=(15,10))
ax = plt.gca()

df.hist(bins=50, ax=ax, layout=(4,4), column=numeric)
plt.tight_layout()
plt.show()
